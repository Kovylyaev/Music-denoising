# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovylyaev/Music_MMLS/blob/main/MUSIC_MMLS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Music MMLS

# %% [markdown]
# # Библотеки

# %%
# !pip install librosa

# %%
# %matplotlib inline
import librosa
import librosa.display
import IPython
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import shutil
import kagglehub
import os

# %% [markdown]
# # Данные

# %% [markdown]
# ## Скачивание данных

# %%
path = kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification")
path = shutil.move(path + '/Data', '/content/sample_data')
# Out:
# ...
# 100%|██████████| 1.21G/1.21G [00:23<00:00, 56.2MB/s]
# Extracting files...

# %%
print(os.listdir(path + '/Data'))
# Out:
# ['images_original', 'features_3_sec.csv', 'genres_original', 'features_30_sec.csv']

# %%
print(os.listdir(genres_folder + '/rock'))
# Out:
# ['rock.00005.wav', 'rock.00067.wav', 'rock.00030.wav', 'rock.00018.wav', 'rock.00010.wav', 'rock.00078.wav', 'rock.00096.wav', 'rock.00045.wav', 'rock.00052.wav', 'rock.00075.wav', 'rock.00085.wav', 'rock.00048.wav', 'rock.00053.wav', 'rock.00041.wav', 'rock.00032.wav', 'rock.00073.wav', 'rock.00076.wav', 'rock.00020.wav', 'rock.00060.wav', 'rock.00006.wav', 'rock.00016.wav', 'rock.00092.wav', 'rock.00014.wav', 'rock.00077.wav', 'rock.00028.wav', 'rock.00023.wav', 'rock.00050.wav', 'rock.00035.wav', 'rock.00047.wav', 'rock.00029.wav', 'rock.00012.wav', 'rock.00025.wav', 'rock.00001.wav', 'rock.00026.wav', 'rock.00091.wav', 'rock.00099.wav', 'rock.00059.wav', 'rock.00065.wav', 'rock.00068.wav', 'rock.00097.wav', 'rock.00019.wav', 'rock.00036.wav', 'rock.00040.wav', 'rock.00034.wav', 'rock.00002.wav', 'rock.00095.wav', 'rock.00033.wav', 'rock.00022.wav', 'rock.00038.wav', 'rock.00089.wav', 'rock.00056.wav', 'rock.00071.wav', 'rock.00074.wav', 'rock.00017.wav', 'rock.00031.wav', 'rock.0
# ...

# %%
genres_folder = path + '/Data/genres_original'

for folder in os.listdir(genres_folder):
  for file in os.listdir(genres_folder + '/' + folder):
    shutil.move(file, path + '/Data/all_records')

print(os.listdir(path + '/Data/all_records'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     852     try:
# --> 853         os.rename(src, real_dst)
#     854     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rock.00005.wav' -> '/root/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data/all_records'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-83f63037d48e> in <cell line: 0>()
#       3 for folder in os.listdir(genres_folder):
#       4   for file in os.listdir(genres_folder + '/' + folder):
# ----> 5     shutil.move(file, path + '/Data/all_records')
#       6
#       7 print(os.listdir(path + '/Data/all_records'))
#
# ...

# %%
data = pd.read_csv(path + '/Data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-15c04837bd3d> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv(path + '/spotify_data.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                        track_id  popularity  year     genre  danceability  \
# ...
